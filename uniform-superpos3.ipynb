# %%
# Ria Patel - June 28, 2019
# Manipulates 3 qubits with Hadamard Gates

# Imports needed libraries/tools
import qiskit as qk
from qiskit import ClassicalRegister, QuantumRegister, QuantumCircuit
from qiskit import execute, Aer
from qiskit import IBMQ
from qiskit.tools.visualization import plot_histogram

# Used for mpl drawing at the end
style = {'backgroundcolor':'#FB7685'}

# Sets up the registers and the circuit
q = QuantumRegister(3)
c = ClassicalRegister(3)
qc = QuantumCircuit(q,c)

# %%
# Measuring qubits before Hadamard Gate is applied
qc.measure(q[0], c[0])
qc.measure(q[1], c[1])
qc.measure(q[2], c[2])

# Simulates the circuit & plots histogram
backend = Aer.get_backend('qasm_simulator')
job_sim = execute(qc, backend, shots=1024)
sim_result = job_sim.result()
measurement_result = sim_result.get_counts(qc)
print(measurement_result)
plot_histogram(measurement_result)
# Out:
# {'000': 1024}

# %%
qc.barrier(q)

# Applies Hadamard Gate to 1st qubit
qc.h(q[0])
qc.measure(q[0], c[0])
qc.measure(q[1], c[1])
qc.measure(q[2], c[2])

# Simulates the circuit & plots histogram
backend = Aer.get_backend('qasm_simulator')
job_sim = execute(qc, backend, shots=1024)
sim_result = job_sim.result()
measurement_result = sim_result.get_counts(qc)
print(measurement_result)
plot_histogram(measurement_result, color = 'green')
# Out:
# {'000': 520, '001': 504}

# %%
qc.barrier(q)

# Resets 1st qubit
qc.reset(q[0])

# Applies Hadamard Gate to 2nd qubit
qc.h(q[1])
qc.measure(q[0], c[0])
qc.measure(q[1], c[1])
qc.measure(q[2], c[2])

# Simulates the circuit & plots histogram
backend = Aer.get_backend('qasm_simulator')
job_sim = execute(qc, backend, shots=1024)
sim_result = job_sim.result()
measurement_result = sim_result.get_counts(qc)
print(measurement_result)
plot_histogram(measurement_result, color = 'green')
# Out:
# {'000': 515, '010': 509}

# %%
qc.barrier(q)

# Resets 2nd qubit
qc.reset(q[1])

# Applies Hadamard Gate to 3rd qubit
qc.h(q[2])
qc.measure(q[0], c[0])
qc.measure(q[1], c[1])
qc.measure(q[2], c[2])

# Simulates the circuit & plots histogram
backend = Aer.get_backend('qasm_simulator')
job_sim = execute(qc, backend, shots=1024)
sim_result = job_sim.result()
measurement_result = sim_result.get_counts(qc)
print(measurement_result)
plot_histogram(measurement_result, color = 'green')
# Out:
# {'000': 488, '100': 536}

# %%
qc.barrier(q)

# Resets 3rd qubit
qc.reset(q[2])

# Applies Hadamard gate on 1st and 2nd qubits
qc.h(q[0])
qc.h(q[1])
qc.measure(q[0], c[0])
qc.measure(q[1], c[1])
qc.measure(q[2], c[2])

# Simulates the circuit & plots histogram
backend = Aer.get_backend('qasm_simulator')
job_sim = execute(qc, backend, shots=1024)
sim_result = job_sim.result()
measurement_result = sim_result.get_counts(qc)
print(measurement_result)
plot_histogram(measurement_result, color = 'green')
# Out:
# {'001': 251, '000': 256, '010': 260, '011': 257}

# %%
qc.barrier(q)

# Resets 2nd qubit
qc.reset(q[1])

# Applies Hadamard gate on 1st and 3rd qubits
qc.h(q[0])
qc.h(q[2])
qc.measure(q[0], c[0])
qc.measure(q[1], c[1])
qc.measure(q[2], c[2])

# Simulates the circuit & plots histogram
backend = Aer.get_backend('qasm_simulator')
job_sim = execute(qc, backend, shots=1024)
sim_result = job_sim.result()
measurement_result = sim_result.get_counts(qc)
print(measurement_result)
plot_histogram(measurement_result, color = 'green')
# Out:
# {'000': 244, '100': 299, '101': 241, '001': 240}

# %%
qc.barrier(q)

# Resets 1st qubit
qc.reset(q[0])

# Applies Hadamard gate on 2nd and 3rd qubits
qc.h(q[1])
qc.h(q[2])
qc.measure(q[0], c[0])
qc.measure(q[1], c[1])
qc.measure(q[2], c[2])

# Simulates the circuit & plots histogram
backend = Aer.get_backend('qasm_simulator')
job_sim = execute(qc, backend, shots=1024)
sim_result = job_sim.result()
measurement_result = sim_result.get_counts(qc)
print(measurement_result)
plot_histogram(measurement_result, color = 'green')
# Out:
# {'000': 241, '100': 256, '010': 251, '110': 276}

# %%
qc.barrier(q)

# Applies Hadamard gate on 1st qubit
qc.h(q[0])
qc.measure(q[0], c[0])
qc.measure(q[1], c[1])
qc.measure(q[2], c[2])

# Simulates the circuit & plots histogram
backend = Aer.get_backend('qasm_simulator')
job_sim = execute(qc, backend, shots=1024)
sim_result = job_sim.result()
measurement_result = sim_result.get_counts(qc)
print(measurement_result)
plot_histogram(measurement_result, color = 'green')
# Out:
# {'010': 115, '110': 138, '000': 136, '100': 118, '011': 128, '111': 128, '001': 141, '101': 120}

# %%
qc.draw(output='mpl', style=style)
