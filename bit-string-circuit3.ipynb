# %%
# All of this manipulates circuit with 3 qubits

# Imports needed libraries/tools
import qiskit as qk
from qiskit import ClassicalRegister, QuantumRegister, QuantumCircuit
from qiskit import execute, Aer
from qiskit import IBMQ
from qiskit.tools.visualization import plot_histogram

# Used for mpl drawing at the end
style = {'backgroundcolor':'lightgreen'}

# Creates quantum circuits
q = QuantumRegister(3)
c = ClassicalRegister(3)
qc = QuantumCircuit(q, c)

# %%
# Measuring for |000> state
qc.measure(q[0], c[0])
qc.measure(q[1], c[1])
qc.measure(q[2], c[2])

# Simulates the circuit & plots histogram
backend = Aer.get_backend('qasm_simulator')
job_sim = execute(qc, backend, shots=1024)
sim_result = job_sim.result()
measurement_result = sim_result.get_counts(qc)
print(measurement_result)
plot_histogram(measurement_result, color = '#FB7685')
# Out:
# {'000': 1024}

# %%
qc.barrier(q)

# Flipping qubit to get |001> state
qc.x(q[0])
qc.measure(q[0], c[0])
qc.measure(q[1], c[1])
qc.measure(q[2], c[2])

# Simulates the circuit & plots histogram
backend = Aer.get_backend('qasm_simulator')
job_sim = execute(qc, backend, shots=1024)
sim_result = job_sim.result()
measurement_result = sim_result.get_counts(qc)
print(measurement_result)
plot_histogram(measurement_result)
# Out:
# {'001': 1024}

# %%
qc.barrier(q)

# Resets qubits to |000> state
qc.reset(q)

# Flips the 2nd qubit to get |010> state
qc.x(q[1])
qc.measure(q[0], c[0])
qc.measure(q[1], c[1])
qc.measure(q[2], c[2])

# Simulates the circuit & plots histogram
backend = Aer.get_backend('qasm_simulator')
job_sim = execute(qc, backend, shots=1024)
sim_result = job_sim.result()
measurement_result = sim_result.get_counts(qc)
print(measurement_result)
plot_histogram(measurement_result)
# Out:
# {'010': 1024}

# %%
qc.barrier(q)

# Flips qubit to get |011>
qc.x(q[0])
qc.measure(q[0], c[0])
qc.measure(q[1], c[1])
qc.measure(q[2], c[2])

# Simulates the circuit & plots histogram
backend = Aer.get_backend('qasm_simulator')
job_sim = execute(qc, backend, shots=1024)
sim_result = job_sim.result()
measurement_result = sim_result.get_counts(qc)
print(measurement_result)
plot_histogram(measurement_result)
# Out:
# {'011': 1024}

# %%
qc.barrier(q)

# Resets qubits to |000> state
qc.reset(q)

# Flips the 2nd qubit to get |100> state
qc.x(q[2])
qc.measure(q[0], c[0])
qc.measure(q[1], c[1])
qc.measure(q[2], c[2])

# Simulates the circuit & plots histogram
backend = Aer.get_backend('qasm_simulator')
job_sim = execute(qc, backend, shots=1024)
sim_result = job_sim.result()
measurement_result = sim_result.get_counts(qc)
print(measurement_result)
plot_histogram(measurement_result)
# Out:
# {'100': 1024}

# %%
qc.barrier(q)

# Flips the 2nd qubit to get |101> state
qc.x(q[0])
qc.measure(q[0], c[0])
qc.measure(q[1], c[1])
qc.measure(q[2], c[2])

# Simulates the circuit & plots histogram
backend = Aer.get_backend('qasm_simulator')
job_sim = execute(qc, backend, shots=1024)
sim_result = job_sim.result()
measurement_result = sim_result.get_counts(qc)
print(measurement_result)
plot_histogram(measurement_result)
# Out:
# {'101': 1024}

# %%
qc.barrier(q)

# Resets qubits to |000> state
qc.reset(q)

# Flips the 2nd qubit to get |110> state
qc.x(q[1])
qc.x(q[2])
qc.measure(q[0], c[0])
qc.measure(q[1], c[1])
qc.measure(q[2], c[2])

# Simulates the circuit & plots histogram
backend = Aer.get_backend('qasm_simulator')
job_sim = execute(qc, backend, shots=1024)
sim_result = job_sim.result()
measurement_result = sim_result.get_counts(qc)
print(measurement_result)
plot_histogram(measurement_result)
# Out:
# {'110': 1024}

# %%
qc.barrier(q)

# Flips qubit to get |111> state
qc.x(q[0])
qc.measure(q[0], c[0])
qc.measure(q[1], c[1])
qc.measure(q[2], c[2])

# Simulates the circuit & plots histogram
backend = Aer.get_backend('qasm_simulator')
job_sim = execute(qc, backend, shots=1024)
sim_result = job_sim.result()
measurement_result = sim_result.get_counts(qc)
print(measurement_result)
plot_histogram(measurement_result, color = '#FB7685')
# Out:
# {'111': 1024}

# %%
qc.draw(output='mpl', style=style)
